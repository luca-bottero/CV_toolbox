# %% [markdown]
# # MTCNN
#
# https://github.com/ipazc/mtcnn

# %%
# With pip:
# !pip3 install mtcnn
# Out:
# /home/luca/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 1.13.1-unknown is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/luca/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /home/luca/.local/lib/python3.8/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...

# %%
from PIL import Image
from mtcnn import MTCNN
import cv2

img = cv2.cvtColor(cv2.imread('800px-Crowd_demonstrates_against_Great_Britain_in_Cairo.jpg'), cv2.COLOR_BGR2RGB)

detector = MTCNN()
detector.detect_faces(img)
# Out:
# [{'box': [626, 509, 49, 60],
#   'confidence': 0.9999984502792358,
#   'keypoints': {'left_eye': (642, 531),
#    'right_eye': (665, 529),
#    'nose': (657, 540),
#    'mouth_left': (645, 554),
#    'mouth_right': (667, 552)}},
#  {'box': [532, 435, 50, 62],
#   'confidence': 0.9999912977218628,
#   'keypoints': {'left_eye': (545, 460),
#    'right_eye': (568, 457),
#    'nose': (557, 470),
#    'mouth_left': (549, 483),
#    'mouth_right': (572, 480)}},
#  {'box': [323, 433, 50, 66],
#   'confidence': 0.9999794960021973,
#   'keypoints': {'left_eye': (336, 457),
#    'right_eye': (360, 455),
#    'nose': (351, 467),
#    'mouth_left': (338, 481),
#    'mouth_right': (362, 480)}},
#  {'box': [697, 384, 47, 59],
#   'confidence': 0.999968409538269,
#   'keypoints': {'left_eye': (710, 404),
#    'right_eye': (732, 406),
#    'nose': (721, 418),
#    'mouth_left': (709, 427),
#    'mouth_right': (730, 429)}},
#  {'box': [263, 432, 39, 50],
#   'confidence': 0.9999480247497559,
# ...
